# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Tweepy Influential Users Twitter Data (Backfill)

# %%
pd.read_csv("../../scraped_tweets/bitcoin_tweets_influential_users.csv", on_bad_lines='skip', decimal=".")
# Out:
# /var/folders/mc/ydz19ftd49sd7q8qgcq53tkh0000gn/T/ipykernel_61323/460234722.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("../../scraped_tweets/bitcoin_tweets_influential_users.csv", on_bad_lines='skip', decimal=".")
#                2022-12-26 00:15:36  1366565625401909249  \
# 0              2022-12-25 22:59:14         1.366566e+18
# 1              2022-12-25 22:53:38         1.366566e+18
# 2              2022-12-25 22:19:14         1.366566e+18
# 3              2022-12-25 20:50:06         1.366566e+18
# 4              2022-12-25 20:39:48         1.366566e+18
# ...                            ...                  ...
# 4012431  2022-08-07 16:15:56+00:00         1.531259e+18
# 4012432  2022-08-07 12:47:21+00:00         1.531259e+18
# 4012433  2022-08-03 19:30:29+00:00         1.531259e+18
# 4012434  2022-07-14 16:28:48+00:00         1.531259e+18
# 4012435  2022-07-14 13:06:23+00:00         1.531259e+18
#
#             🤨conspiracy theory ??? https://t.co/agzkP04dbo      6      30
# 0        Quote: "My mom wanted us to make cute gingerbr...   33.0   457.0
# 1        Died Suddenly at age 37.   Heart attack.  #Die...  251.0  1421.0
# 2         @stillgray Twitter Blue edit feature fixes that.    0.0    47.0
# 3          We could defeat Canada with the Salvation Army.   52.0  1024.0
# 4        This surprise attack by Canada requires retali...  683.0  5568.0
# ...                                                    ...    ...     ...
# 4012431       @KoizumiNFT Can you dm me please @KoizumiNFT    0.0     0.0
# 4012432             @FinanceVolare Check Dm @FinanceVolare    0.0     0.0
# 4012433  #LovelyINU 40 GÜNDE 20 X yaptık 🤝   Henüz kims...  116.0   117.0
# 4012434  RT @Crypto101SA: #VolareFinance Discord Etkinl...  252.0     0.0
# 4012435  RT @Crypto101SA: 🎉ÇEKİLİŞ SAATİ 🎉  300.000 SHİ...  398.0     0.0
#
# [4012436 rows x 5 columns]

# %% [markdown]
# # Bitcoin data

# %%
bitcoin_df = pd.read_csv("../bitcoin_bitstamp.csv", decimal=".", usecols=[
                             "date",
                             "symbol",
                             "open",
                             "high",
                             "low",
                             "close"],
                         parse_dates=['date'])
# date to only be date, not time
from datetime import date, timedelta
bitcoin_df.date = bitcoin_df.date.dt.floor('D')
bitcoin_df["Bitcoin_Fluctuation_nextday"] = np.where((bitcoin_df.open - bitcoin_df.close) < 0, "bearish", "bullish")
# subtract one day so when matching with tweets bitcoin fluctuation of next day will be the label for the tweets of a given day
bitcoin_df.date = bitcoin_df.date - timedelta(days=1)
bitcoin_df.set_index("date", inplace=True)
bitcoin_df_input = bitcoin_df[["Bitcoin_Fluctuation_nextday"]]
df_input.join(bitcoin_df_input)
# Out:
#            Bitcoin_Fluctuation_nextday
# date
# 2022-12-30                     bullish
# 2022-12-29                     bullish
# 2022-12-28                     bearish
# 2022-12-27                     bullish
# 2022-12-26                     bullish
# ...                                ...
# 2016-06-07                     bearish
# 2016-06-06                     bullish
# 2016-06-05                     bearish
# 2016-06-04                     bearish
# 2016-06-03                     bullish
#
# [2402 rows x 1 columns]

# %% [markdown]
# # Kaggle Twitter Data (Backfill)

# %%
df = pd.read_csv("../Kaggle_Bitcoin_tweets.csv",
                        usecols=[
                             "user_name",
                             "user_followers",
                             "user_verified",
                             "date",
                             "text",
                             "hashtags"],
                        dtype={
                             "user_name": str,
                             "user_location": str,
                             "user_description": str,
                             "text": str},
                         parse_dates=['date'],
                        )
# Out:
# /var/folders/mc/ydz19ftd49sd7q8qgcq53tkh0000gn/T/ipykernel_61323/3677581562.py:1: DtypeWarning: Columns (4,7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Kaggle_Bitcoin_tweets.csv",

# %%
df
# Out:
#                                          user_name user_followers  \
# 0                                    DeSota Wilson         8534.0
# 1                                         CryptoND         6769.0
# 2                                        Tdlmatias          128.0
# 3                             Crypto is the future          625.0
# 4         Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader         1249.0
# ...                                            ...            ...
# 57411152                             Bareq Nas 🕗=💸          246.0
# 57411153                                     ALFIE          217.0
# 57411154                           Simo M Bentaleb          565.0
# 57411155                                  😄Dean ⚔️           29.0
# 57411156                                    piGirl          361.0
#
#          user_verified                 date  \
# 0                False  2021-02-10 23:59:04
# 1                False  2021-02-10 23:58:48
# 2                False  2021-02-10 23:54:48
# 3                False  2021-02-10 23:54:33
# 4                False  2021-02-10 23:54:06
# ...                ...                  ...
# 57411152         False  2022-11-20 20:59:39
# 57411153         False  2022-11-20 20:59:01
# 57411154         False  2022-11-20 20:58:56
# 57411155         False  2022-11-20 20:58:50
# 57411156         False  2022-11-20 20:58:33
#
#                                                        text  \
# 0         Blue Ridge Bank shares halted by NYSE after #b...
# 1         😎 Today, that's this #Thursday, we will do a "...
# 2         Guys evening, I have read this article about B...
# 3         $BTC A big chance in a billion! Price: \487264...
# 4         This network is secured by 9 508 nodes as of t...
# ...                                                     ...
# 57411152  When everyone thinks #BTC is going in one dire...
# 57411153  #OP Filled short on this and if it closes as a...
# 57411154  @saylor @dergigi I'm with you on #BTC as a val...
# 57411155  🔽⏰ $CELR Is Cooling Down From 0.01098         ...
# 57411156  @rovercrc Same 💩💩💩 you were saying when 💩 #Btc...
#
#                                                 hashtags
# 0                                            ['bitcoin']
# 1              ['Thursday', 'Btc', 'wallet', 'security']
# 2                                                    NaN
# 3                     ['Bitcoin', 'FX', 'BTC', 'crypto']
# 4                                                ['BTC']
# ...                                                  ...
# 57411152                                         ['BTC']
# 57411153                                   ['OP', 'BTC']
# 57411154  ['BTC', 'Web3', 'Microstrategy', 'BI', 'SAAS']
# 57411155                                         ['btc']
# 57411156                                         ['Btc']
#
# [57411157 rows x 6 columns]

# %%
# change datatype of date
df.date = pd.to_datetime(df.date, errors="coerce")
# drop nas
df_clean = df.dropna()
df_clean = df_clean.convert_dtypes()
df_clean.user_followers = df_clean.user_followers.astype("float")
df_clean.user_verified = df_clean.user_verified.astype(bool)

# %%
df_clean.dtypes
# Out:
# user_name                 string
# user_followers           float64
# user_verified               bool
# date              datetime64[ns]
# text                      string
# hashtags                  string
# dtype: object

# %%
df_clean.sort_values("date")
# Out:
#                         user_name  user_followers  user_verified  \
# 21523              Iconic Holding           301.0           True
# 21524              Iconic Holding           301.0           True
# 21522              Iconic Holding           301.0           True
# 21521              Iconic Holding           301.0           True
# 21520             Nick Doevendans            37.0           True
# ...                           ...             ...            ...
# 49154666             Prateek⚡️⚡⚡⚡           348.0           True
# 49154665             Erik Friesen            14.0           True
# 55246912      Hurricane.Wrists 🥣🌊          1543.0           True
# 49154664  FelixDexter🔺|Crypto|NFT           552.0           True
# 55246911                 Firetrap           757.0           True
#
#                         date  \
# 21523    2021-02-05 10:52:04
# 21524    2021-02-05 10:52:04
# 21522    2021-02-05 10:52:06
# 21521    2021-02-05 10:52:07
# 21520    2021-02-05 10:52:26
# ...                      ...
# 49154666 2022-11-21 23:59:42
# 49154665 2022-11-21 23:59:43
# 55246912 2022-11-21 23:59:45
# 49154664 2022-11-21 23:59:46
# 55246911 2022-11-21 23:59:59
#
#                                                        text  \
# 21523     2⃣   Debunking 9 #Bitcoin Myths by @Patrick_Lo...
# 21524     📖  Weekend Read 📖
#
# Keen to learn about #crypto...
# 21522     4⃣  🎙️ Bloomberg LP #CryptoOutlook 2021 with @...
# 21521     5⃣   #Blockchain 50 2021 by @DelRayMan, @Forbe...
# 21520     #reddcoin #rdd @reddcoin to the moon #altcoin ...
# ...                                                     ...
# 49154666  @adam3us Congrats! Now please help me get to 5...
# 49154665  @saylor @hodlXhold #Bitcoin fans are like Trum...
# 55246912  #btc $btc what are we doing? https://t.co/2br5...
# 49154664  Another giant of the crypto-market is on the v...
# 55246911  Check out what $LIT have been cooking up!!! #1...
#
#                                                    hashtags
# 21523     ['Bitcoin', 'cryptocurrency', 'bitcoin', 'cryp...
# 21524                                            ['crypto']
# 21522     ['CryptoOutlook', 'cryptocurrency', 'bitcoin',...
# 21521     ['Blockchain', 'cryptocurrency', 'bitcoin', 'c...
# 21520     ['reddcoin', 'rdd', 'altcoin', 'turnreddcoinin...
# ...                                                     ...
# 49154666                                        ['Bitcoin']
# 49154665                                        ['Bitcoin']
# 55246912                                            ['btc']
# 49154664                             ['Genesis', 'Bitcoin']
# 55246911        ['100xGems', 'BTC', 'Altcoins', 'VOLTARMY']
#
# [4567609 rows x 6 columns]

# %%
Tags = ["Giveaway","giveaway","Cashback","cashback","Airdrop","nft"]

# %%
# clear tweets with hastags that suggest bots and spam
for tag in Tags:
    df_clean = df_clean[(df_clean['hashtags'].str.contains(tag)==False)&(df_clean['text'].str.contains(tag)==False)]

# %%
# data preprocessing. Remove hashtags, usernames, mentions, emojis, links, Non-ASCII characters, email adresses and special characters from posts
# define functions for different steps

# hashtag removal
import re
import nltk
from nltk.tokenize import RegexpTokenizer

# remove hashtags
def hashtag_removal(text):
  hash = re.findall(r"#(\w+)", text)
  return hash

# %%
from emot.emo_unicode import UNICODE_EMOJI, EMOTICONS_EMO
# translate emoji
def emoji_convert(text):
  for emot in UNICODE_EMOJI:
    if text == None:
      text = text
    else:
      text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",", "").replace(":", "").split()))
    return text

# %%
# remove retweet username and tweeted at @username
def users_removal(tweet):
  '''Takes a string and removes retweet and @user information'''
  tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) 
  # remove tweeted at
  return tweet

# %%
# remove links
def links_removal(tweet):
  '''Takes a string and removes web links from it'''
  tweet = re.sub(r'http\S+', '', tweet) # remove http links
  tweet = re.sub(r'bit.ly/\S+', '', tweet) # remove bitly links
  tweet = tweet.strip('[link]') # remove [links]
  return tweet
def html_clean(text):
  html = re.compile('<.*?>')#regex
  return html.sub(r'',text)

# %%
# remove non ascii character
def non_ascii_removal(s):
  return "".join(i for i in s if ord(i)<128)

def lower(text):
  return text.lower()

# %%
# remove email address
def email_address_removal(text):
  email = re.compile(r'[\w\.-]+@[\w\.-]+')
  return email.sub(r'',text)

# remove punctuation
def punct_removal(text):
  token=RegexpTokenizer(r'\w+')#regex
  text = token.tokenize(text)
  text= " ".join(text)
  return text

# %%
def special_removal(tweet):
  tweet = re.sub('([_]+)', "", tweet)
  return tweet

# %%
#apply all the functions above
df_clean['hashtag'] = df_clean.text.apply(func = hashtag_removal)
df_clean['new_text'] = df_clean.text.apply(func = emoji_convert)
df_clean['new_text'] = df_clean.new_text.apply(func = users_removal)
df_clean['new_text'] = df_clean.new_text.apply(func = html_clean)
df_clean['new_text'] = df_clean.new_text.apply(func = links_removal)
df_clean['new_text'] = df_clean.new_text.apply(func = non_ascii_removal)
df_clean['new_text'] = df_clean.new_text.apply(func = lower)
df_clean['new_text'] = df_clean.new_text.apply(func = email_address_removal)
df_clean['new_text'] = df_clean.new_text.apply(func = punct_removal)
df_clean['new_text'] = df_clean.new_text.apply(func = special_removal)

# %%
df_clean
# Out:
#                                          user_name  user_followers  \
# 0                                    DeSota Wilson          8534.0
# 1                                         CryptoND          6769.0
# 3                             Crypto is the future           625.0
# 4         Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader          1249.0
# 6                                      Bitcoin-Bot           131.0
# ...                                            ...             ...
# 57411152                             Bareq Nas 🕗=💸           246.0
# 57411153                                     ALFIE           217.0
# 57411154                           Simo M Bentaleb           565.0
# 57411155                                  😄Dean ⚔️            29.0
# 57411156                                    piGirl           361.0
#
#           user_verified                date  \
# 0                  True 2021-02-10 23:59:04
# 1                  True 2021-02-10 23:58:48
# 3                  True 2021-02-10 23:54:33
# 4                  True 2021-02-10 23:54:06
# 6                  True 2021-02-10 23:53:17
# ...                 ...                 ...
# 57411152          False 2022-11-20 20:59:39
# 57411153          False 2022-11-20 20:59:01
# 57411154          False 2022-11-20 20:58:56
# 57411155          False 2022-11-20 20:58:50
# 57411156          False 2022-11-20 20:58:33
#
#                                                        text  \
# 0         Blue Ridge Bank shares halted by NYSE after #b...
# 1         😎 Today, that's this #Thursday, we will do a "...
# 3         $BTC A big chance in a billion! Price: \487264...
# 4         This network is secured by 9 508 nodes as of t...
# 6         &lt;'fire' &amp; 'man'&gt;
# #Bitcoin #Crypto #B...
# ...                                                     ...
# 57411152  When everyone thinks #BTC is going in one dire...
# 57411153  #OP Filled short on this and if it closes as a...
# 57411154  @saylor @dergigi I'm with you on #BTC as a val...
# 57411155  🔽⏰ $CELR Is Cooling Down From 0.01098         ...
# 57411156  @rovercrc Same 💩💩💩 you were saying when 💩 #Btc...
#
#                                                 hashtags  \
# 0                                            ['bitcoin']
# 1              ['Thursday', 'Btc', 'wallet', 'security']
# 3                     ['Bitcoin', 'FX', 'BTC', 'crypto']
# 4                                                ['BTC']
# 6                           ['Bitcoin', 'Crypto', 'BTC']
# ...                                                  ...
# 57411152                                         ['BTC']
# 57411153                                   ['OP', 'BTC']
# 57411154  ['BTC', 'Web3', 'Microstrategy', 'BI', 'SAAS']
# 57411155                                         ['btc']
# 57411156                                         ['Btc']
#
#                                        hashtag  \
# 0                                    [bitcoin]
# 1            [Thursday, Btc, wallet, security]
# 3                   [Bitcoin, FX, BTC, crypto]
# 4                                        [BTC]
# 6                       [Bitcoin, Crypto, BTC]
# ...                                        ...
# 57411152                                 [BTC]
# 57411153                             [OP, BTC]
# 57411154  [BTC, Web3, Microstrategy, BI, SAAS]
# 57411155                                 [btc]
# 57411156                                 [Btc]
#
#                                                    new_text
# 0         blue ridge bank shares halted by nyse after bi...
# 1         today that s this thursday we will do a take 2...
# 3         btc a big chance in a billion price 4872644 0 ...
# 4         this network is secured by 9 508 nodes as of t...
# 6                     lt fire amp man gt bitcoin crypto btc
# ...                                                     ...
# 57411152  when everyone thinks btc is going in one direc...
# 57411153  op filled short on this and if it closes as a ...
# 57411154  i m with you on btc as a value asset but web3 ...
# 57411155          celr is cooling down from 0 01098 btc btc
# 57411156  same you were saying when btc was at 69k a yea...
#
# [4055042 rows x 8 columns]

# %%
# only select tweets by users with more than 1000 followers
df_influencers = df_clean[(df_clean.user_followers >= 1000)]
# date to only be date, not time
df_influencers.date = df_influencers.date.dt.floor('D')
# Out:
# /var/folders/mc/ydz19ftd49sd7q8qgcq53tkh0000gn/T/ipykernel_61323/2395829965.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_influencers.date = df_influencers.date.dt.floor('D')

# %%
df_influencers
# Out:
#                                          user_name  user_followers  \
# 0                                    DeSota Wilson          8534.0
# 1                                         CryptoND          6769.0
# 4         Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader          1249.0
# 9                                    DeSota Wilson          8534.0
# 10           @massumeh18 #RefinedWarrior #Activist          1159.0
# ...                                            ...             ...
# 57411122                      Bingo Crypto Scanner          2796.0
# 57411128                       Day Trade Professor          1207.0
# 57411135                         Kiba Inu Official         24442.0
# 57411136                                  Kevin 🎙💥         71662.0
# 57411141          Cryptocurrency Price Predictions          3460.0
#
#           user_verified       date  \
# 0                  True 2021-02-10
# 1                  True 2021-02-10
# 4                  True 2021-02-10
# 9                  True 2021-02-10
# 10                 True 2021-02-10
# ...                 ...        ...
# 57411122          False 2022-11-20
# 57411128          False 2022-11-20
# 57411135          False 2022-11-20
# 57411136          False 2022-11-20
# 57411141          False 2022-11-20
#
#                                                        text  \
# 0         Blue Ridge Bank shares halted by NYSE after #b...
# 1         😎 Today, that's this #Thursday, we will do a "...
# 4         This network is secured by 9 508 nodes as of t...
# 9         .@Tesla’s #bitcoin investment is revolutionary...
# 10        Annnd #btc #Bitcoin is headed even higher now....
# ...                                                     ...
# 57411122  ONEUSDT   1h Near support zone #one #eth #btc ...
# 57411128  Do you believe #Crypto (#BTC  &amp; #ETH) is t...
# 57411135  Kibaswap dark mode looking amazing🔥
# Updates co...
# 57411136  If you STILL have #BTC on centralised exchange...
# 57411141  In Progress
# [Pos] Current Profit($T)
# #BTC[LONG...
#
#                                                    hashtags  \
# 0                                               ['bitcoin']
# 1                 ['Thursday', 'Btc', 'wallet', 'security']
# 4                                                   ['BTC']
# 9                                     ['bitcoin', 'crypto']
# 10                                       ['btc', 'Bitcoin']
# ...                                                     ...
# 57411122  ['one', 'eth', 'btc', 'cryptotrading', 'crypto...
# 57411128                           ['Crypto', 'BTC', 'ETH']
# 57411135                        ['KIBAKREW', 'kiba', 'BTC']
# 57411136                                            ['BTC']
# 57411141  ['BTC', 'ETH', 'ADA', 'SOL', 'XRP', 'BNB', 'DO...
#
#                                                     hashtag  \
# 0                                                 [bitcoin]
# 1                         [Thursday, Btc, wallet, security]
# 4                                                     [BTC]
# 9                                         [bitcoin, crypto]
# 10                                           [btc, Bitcoin]
# ...                                                     ...
# 57411122  [one, eth, btc, cryptotrading, cryptocurrency,...
# 57411128                                 [Crypto, BTC, ETH]
# 57411135                              [KIBAKREW, kiba, BTC]
# 57411136                                              [BTC]
# 57411141  [BTC, ETH, ADA, SOL, XRP, BNB, DOGE, AVAX, TRX...
#
#                                                    new_text
# 0         blue ridge bank shares halted by nyse after bi...
# 1         today that s this thursday we will do a take 2...
# 4         this network is secured by 9 508 nodes as of t...
# 9         s bitcoin investment is revolutionary for cryp...
# 10              annnd btc bitcoin is headed even higher now
# ...                                                     ...
# 57411122  oneusdt 1h near support zone one eth btc crypt...
# 57411128  do you believe crypto btc amp eth is the futur...
# 57411135  kibaswap dark mode looking amazing updates con...
# 57411136  if you still have btc on centralised exchanges...
# 57411141  in progress pos current profit t btc long 2 8 ...
#
# [1265462 rows x 8 columns]

# %%
# df[(pd.DatetimeIndex(df.date).year == 2022)&(pd.DatetimeIndex(df.date).month == 11)&(pd.DatetimeIndex(df.date).day == 19)]
# Out:
# Empty DataFrame
# Columns: [user_name, user_followers, user_verified, date, text, hashtags]
# Index: []

# %%
# df_influencers[(pd.DatetimeIndex(df_influencers.date).year == 2022)&(pd.DatetimeIndex(df_influencers.date).month == 11)&(pd.DatetimeIndex(df_influencers.date).day == 19)]
# Out:
#                                  user_name  user_followers  user_verified  \
# 55252128                       PROFIT BLUE        187398.0           True
# 55252129  Cryptocurrency Price Predictions          3460.0           True
# 55252130                 Live Price Crypto          4095.0           True
# 55252138                      Borsche🌋HFSP          1352.0           True
# 55252152                 Live Price Crypto          4095.0           True
# ...                                    ...             ...            ...
# 57411122              Bingo Crypto Scanner          2796.0          False
# 57411128               Day Trade Professor          1207.0          False
# 57411135                 Kiba Inu Official         24442.0          False
# 57411136                          Kevin 🎙💥         71662.0          False
# 57411141  Cryptocurrency Price Predictions          3460.0          False
#
#                date                                               text  \
# 55252128 2022-11-20  @PeterSchiff #Bitcoin mania is far from over.
# ...
# 55252129 2022-11-20  BITCOIN PRICE PREDICTION
#
# PRICE : RISE⤴ in 60 ...
# 55252130 2022-11-20  #Bitcoin Last Price $16291 #BTC 🚀
# Daily Indica...
# 55252138 2022-11-20  @BTC_Archive "Joe Biden: #bitcoin ... rules.."...
# 55252152 2022-11-20  #Bitcoin Last Price $16293 #BTC 🚀
# Daily Indica...
# ...             ...                                                ...
# 57411122 2022-11-20  ONEUSDT   1h Near support zone #one #eth #btc ...
# 57411128 2022-11-20  Do you believe #Crypto (#BTC  &amp; #ETH) is t...
# 57411135 2022-11-20  Kibaswap dark mode looking amazing🔥
# Updates co...
# 57411136 2022-11-20  If you STILL have #BTC on centralised exchange...
# 57411141 2022-11-20  In Progress
# [Pos] Current Profit($T)
# #BTC[LONG...
#
#                                                    hashtags
# 55252128                                ['Bitcoin', 'gold']
# 55252129            ['Bitcoin', 'BTC', 'Python', 'Binance']
# 55252130  ['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Blockch...
# 55252138                                        ['bitcoin']
# 55252152    ['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Crypto']
# ...                                                     ...
# 57411122  ['one', 'eth', 'btc', 'cryptotrading', 'crypto...
# 57411128                           ['Crypto', 'BTC', 'ETH']
# 57411135                        ['KIBAKREW', 'kiba', 'BTC']
# 57411136                                            ['BTC']
# 57411141  ['BTC', 'ETH', 'ADA', 'SOL', 'XRP', 'BNB', 'DO...
#
# [1810 rows x 6 columns]

# %%
df_influencers.to_csv("./kaggle_bitcoin_clean.csv")

# %% [markdown]
# # Preprocessing: Sentiment Analysis

# %%
# import library "textblob" for sentiment analysis
from textblob import TextBlob

# %%
# create a function to get the subjectivity
def getSubjectivity(twt):
    return TextBlob(twt).sentiment.subjectivity

# create a function to get the polarity
def getPolarity(twt):
    return TextBlob(twt).sentiment.polarity

# %%
# determine subjectivity and polarity of the tweets
df_influencers['subjectivity'] = df_influencers['new_text'].apply(getSubjectivity)
df_influencers['polarity'] = df_influencers['new_text'].apply(getPolarity)
# Out:
# /var/folders/mc/ydz19ftd49sd7q8qgcq53tkh0000gn/T/ipykernel_61323/1728617255.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_influencers['subjectivity'] = df_influencers['new_text'].apply(getSubjectivity)
# /var/folders/mc/ydz19ftd49sd7q8qgcq53tkh0000gn/T/ipykernel_61323/1728617255.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_influencers['polarity'] = df_influencers['new_text'].apply(getPolarity)

# %%
df_influencers.iloc[2].text
# Out:
# 'This network is secured by 9 508 nodes as of today. Soon, the biggest bears will recognise: #BTC in too big to fail… https://t.co/1XovDA8rKw'

# %%
df_final = df_influencers[["user_followers","user_verified","date","new_text","subjectivity","polarity"]]

# %%
df_final.to_csv("./kaggle_bitcoin_sentiment.csv")

# %%
# group by days for test
df_final.groupby(pd.Grouper(key='date',freq='D')).mean().dropna()
# Out:
# /var/folders/mc/ydz19ftd49sd7q8qgcq53tkh0000gn/T/ipykernel_61323/3683996174.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_final.groupby(pd.Grouper(key='date',freq='D')).mean().dropna()
#             user_followers  user_verified  subjectivity  polarity
# date
# 2021-02-05    12008.739382       1.000000      0.245410  0.079253
# 2021-02-06    13667.619095       1.000000      0.205079  0.066633
# 2021-02-07     8763.762712       1.000000      0.253386  0.108692
# 2021-02-08    22026.919118       1.000000      0.247273  0.090154
# 2021-02-09    18454.811616       1.000000      0.232901  0.077414
# ...                    ...            ...           ...       ...
# 2022-11-14    37116.944628       1.000000      0.328898  0.078665
# 2022-11-15    31648.634182       1.000000      0.325823  0.091072
# 2022-11-16    26139.847580       1.000000      0.303059  0.096180
# 2022-11-20    25470.349724       0.627624      0.263426  0.074591
# 2022-11-21    31385.786718       1.000000      0.293204  0.087639
#
# [214 rows x 4 columns]

# %%
# group by days for test
d = {'user_followers':'aggregate_followers', 'user_verified':'verified_median','subjectivity':'subjectivity_mean','polarity':'polarity_mean'}
df_input = df_final.groupby(pd.Grouper(key='date',freq='D')).agg({'user_followers':'sum', 'user_verified':'median','subjectivity':'mean','polarity':'mean'}).rename(columns=d).dropna()
print(df_input.verified_median.value_counts())
df_input
# Out:
# 0.0    145
# 1.0     69
# Name: verified_median, dtype: int64
#             aggregate_followers  verified_median  subjectivity_mean  \
# date
# 2021-02-05            6220527.0              1.0           0.245410
# 2021-02-06           13599281.0              1.0           0.205079
# 2021-02-07            7755930.0              1.0           0.253386
# 2021-02-08           41939254.0              1.0           0.247273
# 2021-02-09           24784812.0              1.0           0.232901
# ...                         ...              ...                ...
# 2022-11-14          146129411.0              1.0           0.328898
# 2022-11-15          238693999.0              1.0           0.325823
# 2022-11-16          228436128.0              1.0           0.303059
# 2022-11-20           46101333.0              1.0           0.263426
# 2022-11-21          236774375.0              1.0           0.293204
#
#             polarity_mean
# date
# 2021-02-05       0.079253
# 2021-02-06       0.066633
# 2021-02-07       0.108692
# 2021-02-08       0.090154
# 2021-02-09       0.077414
# ...                   ...
# 2022-11-14       0.078665
# 2022-11-15       0.091072
# 2022-11-16       0.096180
# 2022-11-20       0.074591
# 2022-11-21       0.087639
#
# [214 rows x 4 columns]

# %% [markdown]
# # Twitter API for batch data

# %%
import tweepy, datetime, time

# %%
import configparser

# Read the config file
config = configparser.ConfigParser()
config.read('./Twitter/config.ini')

# Read the values
api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']
access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
# client = MongoClient('localhost', 27017)
# db = client['twitter_db']
# collection = db['usa_collection']
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
# function to perform data extraction
def scrape(keyword, date_until, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=[     'time',
                                        'username',
                                        'description',
                                        'location',
                                        'following',
                                        'followers',
                                        'totaltweets',
                                        'retweetcount',
                                        'text',
                                        'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search_tweets,
                               keyword, lang="en",
                               until=date_until,
                               tweet_mode='extended',
                               count=200).items(numtweet)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
                time = tweet.created_at
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [time, username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                i = i+1
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        # db.to_csv(filename)
        return db

# %%
keyword = "bitcoin"

# %%
from datetime import date, timedelta
today = str(date.today())
yesterday = str(date.today() - timedelta(days = 1))
specific_day = date(2022,12,23)
specific_day_str = str(specific_day)
print(f"Today's date: {today}")
print(f"Yesterdays's date: {yesterday}")
print(f"Specific day's date: {specific_day}")
# Out:
# Today's date: 2022-12-26
# Yesterdays's date: 2022-12-25
# Specific day's date: 2022-12-23

# %%
# scrape 10_000 most recent tweets from yesterday related to "bitcoin"
tweets_df = scrape(keyword, date_until=specific_day_str, numtweet=10_000)
# Out:
# Rate limit reached. Sleeping for: 475

# %%
tweets_df
# Out:
#                           time         username  \
# 0    2022-12-22 23:59:59+00:00    LeoN_ardSanto
# 1    2022-12-22 23:59:59+00:00      AmoneShindo
# 2    2022-12-22 23:59:58+00:00   SilvesterALe17
# 3    2022-12-22 23:59:57+00:00   Rudhrax_Oberoi
# 4    2022-12-22 23:59:57+00:00     MattMoore_Ok
# ...                        ...              ...
# 9995 2022-12-22 22:28:26+00:00      eventiparis
# 9996 2022-12-22 22:28:26+00:00          Oranijo
# 9997 2022-12-22 22:28:24+00:00    Doria01343619
# 9998 2022-12-22 22:28:23+00:00     weeblueghost
# 9999 2022-12-22 22:28:23+00:00  redditmoonshots
#
#                                             description  \
# 0     Interested in the Crypto Space? Want to invest...
# 1
# 2                             $VRA $DOGE $ETH ♥️Pinay♥️
# 3
# 4     🇺🇸’s Syndicated #Bitcoin Radio Host🎙, Consulta...
# ...                                                 ...
# 9995  EVENTIPARIS Association Culturelle Artistique ...
# 9996          Just like Ron Burgundy, I'll say anything
# 9997  Life is short. Make each second count. And enj...
# 9998  I'm a wee blue ghost haunting Twitter with Bit...
# 9999  This subreddit is an UNCENSORED forum for Cryp...
#
#                          location  following  followers  totaltweets  \
# 0                 New Mexico, USA         92         28         1273
# 1                                         58          3           27
# 2     Bandung Djokja INDONESIA 🇲🇨        448        287        10286
# 3                   United States       2681        771        29018
# 4                       Tulsa, OK        763        658         2762
# ...                           ...        ...        ...          ...
# 9995                Paris, France       1585        236         1715
# 9996                       Canada        117        121          649
# 9997                United States         11         56          521
# 9998                                      81        392        95077
# 9999                     Universe        150      48963          285
#
#       retweetcount                                               text  \
# 0                0  @financialjuice There are very good strategies...
# 1            39149  🔊 We've been working for months on the 1st #ro...
# 2              751  "We need more pain before we make a bottom"\n\...
# 3              238  NEW - Legendary investor Bill Miller is still ...
# 4                0  Do you use Blu Studio from @MarketSooner to re...
# ...            ...                                                ...
# 9995           159  Brazil embraces #bitcoin 🇧🇷\n\nhttps://t.co/1p...
# 9996             0  1.66 Trillion USD, that's gotta be bullish for...
# 9997             0  @CoinDesk @FTX_Official @SBF_FTX The #bitcoin ...
# 9998             0  - \nBTC price: $16,801 / £14,039 \n\n59.52 Nak...
# 9999             0  According to #CoinMarketCap for the past year ...
#
#                                                hashtags
# 0                                                    []
# 1                                       [rollups, NEVM]
# 2                                                    []
# 3                                             [Bitcoin]
# 4     [Bitcoin, radio, LA, Atlanta, Seattle, btc, po...
# ...                                                 ...
# 9995                                          [bitcoin]
# 9996                                 [Bitcoin, Bitcoin]
# 9997                                          [bitcoin]
# 9998              [Nak, Bitcoin, Sats, SatoshiNakamoto]
# 9999                           [CoinMarketCap, bitcoin]
#
# [10000 rows x 10 columns]

# %%
import os
save_path = "./scraped_tweets"
if os.path.exists(save_path):
    print(f"Directory {save_path} already created")
else:
    os.mkdir(save_path)
    print("Directory '% s' created" % save_path)
# Out:
# Directory ./scraped_tweets already created

# %%
tweets_df.to_csv(f"{save_path}/bitcoin_tweets_{str(specific_day - timedelta(days=1))}_10k.csv")

# %%
pd.read_csv(f"{save_path}/bitcoin_tweets_{str(specific_day - timedelta(days=1))}_10k.csv")
# Out:
# /var/folders/mc/ydz19ftd49sd7q8qgcq53tkh0000gn/T/ipykernel_30560/1020427271.py:1: DtypeWarning: Columns (1,2,3,4,5,6,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(f"{save_path}/bitcoin_tweets_{str(specific_day - timedelta(days=1))}_10k.csv")
#         Unnamed: 0                       time         username  \
# 0                0  2022-12-22 23:59:59+00:00    LeoN_ardSanto
# 1                1  2022-12-22 23:59:59+00:00      AmoneShindo
# 2                2  2022-12-22 23:59:58+00:00   SilvesterALe17
# 3                3  2022-12-22 23:59:57+00:00   Rudhrax_Oberoi
# 4                4  2022-12-22 23:59:57+00:00     MattMoore_Ok
# ...            ...                        ...              ...
# 2163003       9995  2022-12-22 22:28:26+00:00      eventiparis
# 2163004       9996  2022-12-22 22:28:26+00:00          Oranijo
# 2163005       9997  2022-12-22 22:28:24+00:00    Doria01343619
# 2163006       9998  2022-12-22 22:28:23+00:00     weeblueghost
# 2163007       9999  2022-12-22 22:28:23+00:00  redditmoonshots
#
#                                                description  \
# 0        Interested in the Crypto Space? Want to invest...
# 1                                                      NaN
# 2                                $VRA $DOGE $ETH ♥️Pinay♥️
# 3                                                      NaN
# 4        🇺🇸’s Syndicated #Bitcoin Radio Host🎙, Consulta...
# ...                                                    ...
# 2163003  EVENTIPARIS Association Culturelle Artistique ...
# 2163004          Just like Ron Burgundy, I'll say anything
# 2163005  Life is short. Make each second count. And enj...
# 2163006  I'm a wee blue ghost haunting Twitter with Bit...
# 2163007  This subreddit is an UNCENSORED forum for Cryp...
#
#                             location following followers  totaltweets  \
# 0                    New Mexico, USA      92.0        28       1273.0
# 1                                NaN      58.0         3         27.0
# 2        Bandung Djokja INDONESIA 🇲🇨     448.0       287      10286.0
# 3                      United States    2681.0       771      29018.0
# 4                          Tulsa, OK     763.0       658       2762.0
# ...                              ...       ...       ...          ...
# 2163003                Paris, France    1585.0     236.0       1715.0
# 2163004                       Canada     117.0     121.0        649.0
# 2163005                United States      11.0      56.0        521.0
# 2163006                          NaN      81.0     392.0      95077.0
# 2163007                     Universe     150.0   48963.0        285.0
#
#          retweetcount                                               text  \
# 0                 0.0  @financialjuice There are very good strategies...
# 1             39149.0  🔊 We've been working for months on the 1st #ro...
# 2               751.0  "We need more pain before we make a bottom"\n\...
# 3               238.0  NEW - Legendary investor Bill Miller is still ...
# 4                 0.0  Do you use Blu Studio from @MarketSooner to re...
# ...               ...                                                ...
# 2163003         159.0  Brazil embraces #bitcoin 🇧🇷\n\nhttps://t.co/1p...
# 2163004           0.0  1.66 Trillion USD, that's gotta be bullish for...
# 2163005           0.0  @CoinDesk @FTX_Official @SBF_FTX The #bitcoin ...
# 2163006           0.0  - \nBTC price: $16,801 / £14,039 \n\n59.52 Nak...
# 2163007           0.0  According to #CoinMarketCap for the past year ...
#
#                                                   hashtags
# 0                                                       []
# 1                                      ['rollups', 'NEVM']
# 2                                                       []
# 3                                              ['Bitcoin']
# 4        ['Bitcoin', 'radio', 'LA', 'Atlanta', 'Seattle...
# ...                                                    ...
# 2163003                                        ['bitcoin']
# 2163004                             ['Bitcoin', 'Bitcoin']
# 2163005                                        ['bitcoin']
# 2163006      ['Nak', 'Bitcoin', 'Sats', 'SatoshiNakamoto']
# 2163007                       ['CoinMarketCap', 'bitcoin']
#
# [2163008 rows x 11 columns]
